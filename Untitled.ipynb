# %%
import numpy as np
import cv2
import glob
import matplotlib.pyplot as plt
import matplotlib.image as mping
get_ipython().run_line_magic('matplotlib', 'qt')

import imageio
#imageio.plugins.ffmpeg.download()
from moviepy.editor import VideoFileClip, ImageClip
from IPython.display import HTML
get_ipython().run_line_magic('matplotlib', 'inline')

# %%
objpoint=np.zeros((9*6,3),np.float32)
objpoint[:,:2]=np.mgrid[0:9,0:6].T.reshape(-1,2)
#print("ObjShape",objpoint)

objpoints=[] #3d points in real world
imagepoints=[] #2d ponits in image plane
objpoints1=[] #3d points in real world
imagepoints1=[] #2d ponits in image plane

images=glob.glob('camera_cal/calibration*.jpg')

for fimages in images:
    img=mping.imread(fimages)
    gray=cv2.cvtColor(img,cv2.COLOR_RGB2GRAY)
    #gray1=cv2.cvtColor(img,cv2.COLOR_RGB2HLS)
    
    #S=gray[::2]
    ret,corners=cv2.findChessboardCorners(gray,(9,6),None)
    
    #ret1,corners1=cv2.findChessboardCorners(gray1,(9,6),None)
    
    if(ret==1):
        
        objpoints.append(objpoint)
        imagepoints.append(corners)
        cv2.drawChessboardCorners(img,(9,6),corners,ret)
        
        cv2.imshow('img', img)
        cv2.waitKey(500)
#     if(ret1==1):
#         objpoints1.append(objpoint)
#         imagepoints1.append(corners1)
#         cv2.drawChessboardCorners(img,(9,6),corners1,ret1)
        
#         cv2.imshow('img', img)
#         cv2.waitKey(500)
cv2.destroyAllWindows()

# %%
get_ipython().run_line_magic('matplotlib', 'inline')
image=mping.imread('camera_cal/calibration2.jpg')
img_size=(image.shape[0],image.shape[1])

ret,mtx,dist,rvec,trvec=cv2.calibrateCamera(objpoints,imagepoints,img_size,None,None)
#ret1,mtx1,dist1,rvec1,trvec1=cv2.calibrateCamera(objpoints1,imagepoints1,img_size,None,None)

undistort=cv2.undistort(image,mtx,dist,None,mtx)
#undistort1=cv2.undistort(image,mtx1,dist1,None,mtx1)

cv2.imwrite('output_images/test_undist.jpg',undistort)
#cv2.imwrite('output_images/test_undist1.jpg',undistort1)

f, (ax1, ax2) = plt.subplots(1, 2, figsize=(20,10))
ax1.imshow(image)
ax1.set_title('Original Image', fontsize=30)
ax2.imshow(undistort)
ax2.set_title('Undistorted Image', fontsize=30)
# ax3.imshow(undistort1)
# ax3.set_title('Undistorted Image', fontsize=30)

# %%
def color_gradient(img,sobel_kernel=3, s_thresh=(160, 230), sx_thresh=(60, 150)):
    img = np.copy(img)
    # Convert to HLS color space and separate the V channel
    hls = cv2.cvtColor(img, cv2.COLOR_RGB2HLS).astype(np.float)
    l_channel = hls[:,:,1]
    s_channel = hls[:,:,2]
    
    #gray = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY).astype(np.float)
    
    r_channel=img[:,:,0]
   
        
    # Sobel x
    sobelx = cv2.Sobel(s_channel, cv2.CV_64F, 1, 0,ksize=sobel_kernel) # Take the derivative in x
    abs_sobelx = np.absolute(sobelx) # Absolute x derivative to accentuate lines away from horizontal
    scaled_sobel = np.uint8(255*abs_sobelx/np.max(abs_sobelx))
    sobely = cv2.Sobel(s_channel, cv2.CV_64F, 0, 1,ksize=sobel_kernel) # Take the derivative in x
    
    #abs_sobel = np.sqrt(sobelx**2+sobely**2) # Absolute x derivative to accentuate lines away from horizontal
    #scaled_sobel = np.uint8(255*abs_sobel/np.max(abs_sobel))
    thresh=(0.7, 1.3)
    magnitude=np.arctan2(np.absolute(sobely), np.absolute(sobelx))
    
    # Sobel x
    sobelx_R = cv2.Sobel(r_channel, cv2.CV_64F, 1, 0,ksize=sobel_kernel) # Take the derivative in x
    abs_sobelx_R = np.absolute(sobelx_R) # Absolute x derivative to accentuate lines away from horizontal
    scaled_sobel_R = np.uint8(255*abs_sobelx_R/np.max(abs_sobelx_R))
    
    
    
    # Threshold x gradient
    sxbinary = np.zeros_like(scaled_sobel)
    sxbinary[(scaled_sobel >= sx_thresh[0]) & (scaled_sobel <= sx_thresh[1]) & (magnitude >= thresh[0]) & (magnitude <=thresh[1])] = 1
    
    # Threshold x gradient
    sxbinary_R = np.zeros_like(scaled_sobel_R)
    sxbinary_R[(scaled_sobel_R >= sx_thresh[0]) & (scaled_sobel_R <= sx_thresh[1])] = 1
    
    # Threshold color channel
    s_binary = np.zeros_like(s_channel)
    s_binary[(s_channel >= s_thresh[0]) & (s_channel <= s_thresh[1])] = 1
    
    # Threshold color channel
    s_binary_R = np.zeros_like(r_channel)
    s_binary_R[(r_channel >= s_thresh[0]) & (r_channel <= s_thresh[1])] = 1
    # Stack each channel
    # Note color_binary[:, :, 0] is all 0s, effectively an all black image. It might
    # be beneficial to replace this channel with something else.
    color_binary = np.dstack(( np.zeros_like(sxbinary),sxbinary,s_binary_R)) * 255
    
    # Combine the two binary thresholds
    combined_binary = np.zeros_like(sxbinary)
    combined_binary[((s_binary == 1)&(s_binary_R == 1)) | ((sxbinary == 1)|(sxbinary_R == 1))] = 1
    return combined_binary,color_binary

# %%
def corners_unwarp_lane_lines(img, nx, ny, mtx, dist):
        undistorted=cv2.undistort(img,mtx,dist,None,mtx)
        #gray = cv2.cvtColor(undistorted, cv2.COLOR_BGR2GRAY)
        #ret, corners=cv2.findChessboardCorners(gray,(nx,ny),None)

        #if(ret==True):

            #cv2.drawChessboardCorners(undistorted, (nx, ny), corners, ret)
        img_size=(gray.shape[1], gray.shape[0])
        #print(img_size)
        src=np.float32([(564, 460),(730, 460),(180, 690),(1400, 690)])
        #d=100
        dst=np.float32([(100, 0), (1180, 0), 
                                     (100, 720), 
                                     (1180, 720)])

        M_unwrap=cv2.getPerspectiveTransform(src,dst)

        Mvin=cv2.getPerspectiveTransform(dst,src)

        wrapped=cv2.warpPerspective(img,M_unwrap,img_size,flags=cv2.INTER_LINEAR)
        


        return wrapped, M_unwrap,Mvin,undistorted

# %%
def generate_X_Y(nonzeroy,nonzerox,left_lane_inds,right_lane_inds,img):
    
#     left_lane= np.concatenate(left_lane_inds)
#     right_lane = np.concatenate(right_lane_inds)

    # Extract left and right line pixel positions
    leftx = nonzerox[left_lane_inds]
    lefty = nonzeroy[left_lane_inds] 
    rightx = nonzerox[right_lane_inds]
    righty = nonzeroy[right_lane_inds] 

    # Fit a second order polynomial to each
    left_fit = np.polyfit(lefty, leftx, 2)
    right_fit = np.polyfit(righty, rightx, 2)

    ploty = np.linspace(0, img.shape[0]-1, img.shape[0] )
    left_fitx = left_fit[0]*ploty**2 + left_fit[1]*ploty + left_fit[2]
    right_fitx = right_fit[0]*ploty**2 + right_fit[1]*ploty + right_fit[2]
    
    return right_fitx,left_fitx


def predict_histogram(binary_warped):
    
    histogram = np.sum(binary_warped[binary_warped.shape[0]//2:,:], axis=0)
    
    out_img = np.dstack((binary_warped, binary_warped, binary_warped))*255
    # Find the peak of the left and right halves of the histogram
    # These will be the starting point for the left and right lines
    midpoint = np.int(histogram.shape[0]/2)
    leftx_base = np.argmax(histogram[:midpoint])
    rightx_base = np.argmax(histogram[midpoint:]) + midpoint

    # Choose the number of sliding windows
    nwindows = 9
    # Set height of windows
    window_height = np.int(binary_warped.shape[0]/nwindows)
    # Identify the x and y positions of all nonzero pixels in the image
    nonzero = binary_warped.nonzero()
    nonzeroy = np.array(nonzero[0])
    nonzerox = np.array(nonzero[1])
    # Current positions to be updated for each window
    leftx_current = leftx_base
    rightx_current = rightx_base
    # Set the width of the windows +/- margin
    margin = 100
    # Set minimum number of pixels found to recenter window
    minpix = 50
    # Create empty lists to receive left and right lane pixel indices
    left_lane_inds = []
    right_lane_inds = []

    # Step through the windows one by one
    for window in range(nwindows):
        # Identify window boundaries in x and y (and right and left)
        win_y_low = binary_warped.shape[0] - (window+1)*window_height
        win_y_high = binary_warped.shape[0] - window*window_height
        win_xleft_low = leftx_current - margin
        win_xleft_high = leftx_current + margin
        win_xright_low = rightx_current - margin
        win_xright_high = rightx_current + margin
        # Draw the windows on the visualization image
        cv2.rectangle(out_img,(win_xleft_low,win_y_low),(win_xleft_high,win_y_high),
        (0,255,0), 2) 
        cv2.rectangle(out_img,(win_xright_low,win_y_low),(win_xright_high,win_y_high),
        (0,255,0), 2) 
        # Identify the nonzero pixels in x and y within the window
        good_left_inds = ((nonzeroy >= win_y_low) & (nonzeroy < win_y_high) & 
        (nonzerox >= win_xleft_low) &  (nonzerox < win_xleft_high)).nonzero()[0]
        good_right_inds = ((nonzeroy >= win_y_low) & (nonzeroy < win_y_high) & 
        (nonzerox >= win_xright_low) &  (nonzerox < win_xright_high)).nonzero()[0]
        # Append these indices to the lists
        left_lane_inds.append(good_left_inds)
        right_lane_inds.append(good_right_inds)
        # If you found > minpix pixels, recenter next window on their mean position
        if len(good_left_inds) > minpix:
            leftx_current = np.int(np.mean(nonzerox[good_left_inds]))
        if len(good_right_inds) > minpix:        
            rightx_current = np.int(np.mean(nonzerox[good_right_inds]))

    # Concatenate the arrays of indices
    left_lane_inds = np.concatenate(left_lane_inds)
    right_lane_inds = np.concatenate(right_lane_inds)
    
    right_generated,left_generated=generate_X_Y(nonzeroy,nonzerox,left_lane_inds,right_lane_inds,img)
    
    return right_generated,left_generated

# %%
# Define a class to receive the characteristics of each line detection
class Line():
    def __init__(self):
        # was the line detected in the last iteration?
        self.detected = False  
        # x values of the last n fits of the line
        self.recent_xfitted = [] 
        #average x values of the fitted line over the last n iterations
        self.bestx = None     
        #polynomial coefficients averaged over the last n iterations
        self.best_fit = None  
        #polynomial coefficients for the most recent fit
        self.current_fit = [np.array([False])]  
        #radius of curvature of the line in some units
        self.radius_of_curvature = None 
        #distance in meters of vehicle center from the line
        self.line_base_pos = None 
        #difference in fit coefficients between last and new fits
        self.diffs = np.array([0,0,0], dtype='float') 
        #x values for detected line pixels
        self.allx = None  
        #y values for detected line pixels
        self.ally = None

# %%
test_img_unwrap=[]
def pipelines(img):
    
    
    global left_lane
    global right_lane
    
    kernel_size = 9
    blur_img = cv2.GaussianBlur(img,(kernel_size, kernel_size), 0)
    
    #low_threshold = 1
    #high_threshold = 10
    #r_channel = cv2.Canny(r_channel, 50, 150)
    test_out_image,color_binary=color_gradient(blur_img,sobel_kernel=31)
    #print(test_out_image)
    test_img_unwrap.append(test_out_image)
    wrap, perspective_M_unwrap,Mvin,undistorted = corners_unwarp_lane_lines(test_out_image, 9, 6, mtx, dist)
    
    nonzero = wrap.nonzero()
    nonzeroy = np.array(nonzero[0])
    nonzerox = np.array(nonzero[1])
    
    
    color_warp = np.dstack((wrap, wrap, wrap))*255
    color_warp[nonzeroy[left_lane_inds], nonzerox[left_lane_inds]] = [255, 0, 0]
    color_warp[nonzeroy[right_lane_inds], nonzerox[right_lane_inds]] = [0, 0, 255]

    
    ploty = np.linspace(0, wrap.shape[0]-1, wrap.shape[0] )
    
    if (left_lane is None) or (right_lane is None):
        right_predicted,left_predicted= predict_histogram(wrap)
        
    else:
        margin = 100
        left_predicted = left_lane[0]*nonzeroy**2 + left_lane[1]*nonzeroy + left_lane[2]
        
        left_lane_inds =  ((nonzerox > left_predicted - margin) & (nonzerox <= left_predicted + margin)).nonzero()[0] 
        
        right_predicted= right_lane[0]*nonzeroy**2 + right_lane[1]*nonzeroy + right_lane[2]
        
        right_lane_inds  = ((nonzerox > right_predicted - margin) & (nonzerox <= right_predicted + margin)).nonzero()[0] 
        
        
        
        right_predicted,left_predicted=generate_X_Y(nonzeroy,nonzerox,left_lane_inds,right_lane_inds,wrap)
        
#     left_line_window1 = np.array([np.transpose(np.vstack([left_fitx-margin, ploty]))])
#     left_line_window2 = np.array([np.flipud(np.transpose(np.vstack([left_fitx+margin, 
#                                   ploty])))])
#    left_line_pts = np.hstack((left_line_window1, left_line_window2))
    
    
#     right_line_window1 = np.array([np.transpose(np.vstack([right_fitx-margin, ploty]))])
#     right_line_window2 = np.array([np.flipud(np.transpose(np.vstack([right_fitx+margin, 
#                                   ploty])))])
#    right_line_pts = np.hstack((right_line_window1, right_line_window2))
    
    left_line_pts = np.array([np.transpose(np.vstack([left_predicted, ploty]))])
    right_line_pts = np.array([np.flipud(np.transpose(np.vstack([right_predicted, ploty])))])
    pts = np.vstack([left_line_pts, right_line_pts])

    
    # Define conversions in x and y from pixels space to meters
    ym_per_pix = 30/720 # meters per pixel in y dimension
    xm_per_pix = 3.7/700 # meters per pixel in x dimension
    y_eval = np.max(ploty)
    
    # Fit new polynomials to x,y in world space
    left_fit_cr = np.polyfit(ploty*ym_per_pix, left_predicted*xm_per_pix, 2)
    right_fit_cr = np.polyfit(ploty*ym_per_pix, right_predicted*xm_per_pix, 2)
    # Calculate the new radii of curvature
    left_curverad = ((1 + (2*left_fit_cr[0]*y_eval*ym_per_pix + left_fit_cr[1])**2)**1.5) / np.absolute(2*left_fit_cr[0])
    right_curverad = ((1 + (2*right_fit_cr[0]*y_eval*ym_per_pix + right_fit_cr[1])**2)**1.5) / np.absolute(2*right_fit_cr[0])
    
    cv2.fillPoly(color_warp, np.int_([pts]), (0,255, 0))
    unwarped = cv2.warpPerspective(wrap, M_inv, img_size , flags=cv2.INTER_LINEAR)

    result = cv2.addWeighted(img, 1, unwarped, 0.3, 0)

# %%
import os
####code for test videos
if os.path.isdir("test_videos_output"):
    pass
else:
    os.mkdir("test_videos_output")
    
left_lane=None
right_lane=None

def process_image(image):
    # NOTE: The output you return should be a color image (3 channel) for processing video below
    # TODO: put your pipeline here,
    # you should return the final output (image with lines are drawn on lanes)

    result = pipelines(image)
    return result

white_output = 'project_video_test.mp4'
clip1 = VideoFileClip("C:\\Users\\user\\Desktop\\project_video.mp4")
white_clip = clip1.fl_image(process_image) #NOTE: this function expects color images!!

get_ipython().run_line_magic('time', 'white_clip.write_videofile(white_output, audio=False)')
clip1.reader.close()
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-9-54766b7e139a> in <module>()
#      19 white_output = 'project_video_test.mp4'
#      20 clip1 = VideoFileClip("C:\\Users\\user\\Desktop\\project_video.mp4")
# ---> 21 white_clip = clip1.fl_image(process_image) #NOTE: this function expects color images!!
#      22
#      23 get_ipython().run_line_magic('time', 'white_clip.write_videofile(white_output, audio=False)')
#
# ~\Miniconda3\envs\carnd-term1\lib\site-packages\moviepy\video\VideoClip.py in fl_image(self, image_func, apply_to)
#     531         `get_frame(t)` by another frame,  `image_func(get_frame(t))`
#     532         """
# --> 533         return self.fl(lambda gf, t: image_func(gf(t)), apply_to)
#     534
#     535     # --------------------------------------------------------------
#
# ...
